# %%
import pandas as pd
import numpy as np
import sys
import os, os.path

# %% [markdown]
# The purpose of this experiment is to figure out how to best automate a larger number of searches on the beta server.  The goal, is to search all existing public datasets on the beta server with 'core_metabolome_v3' for the 'H2O' neutral loss, at FDR=0.5.  Data will later be filtered to FDR<=0.2 for parent, and FDR<=0.5 for neutral loss, since the current FDR calculations may unfairly penalize neutral losses.
#
# Here, we will use a subset of "high-quality" datasets from the top-4 labs submitting orbitrap/FTMS in the positive and negative ion modes.
#
# Data will be searched against a "core metabolome DB".

# %% [markdown]
# #Off-line steps:
# 1. Metadata as csv was downloaded from: https://beta.metaspace2020.eu/ on 2020 Feb 06.
# 2. Data were imported into Google Sheets, since formatting is comma seperated but then there are commas in text files:
# https://docs.google.com/spreadsheets/d/1DOLikG1euG-brCrMB5jrKwiu7bknPUVGVf8JsZXY3hM/edit?usp=sharing
# 3. Data were further filtered for quality as described above in: "neutral_loss/good_nl_reports/high_quality_data_investigations.ipynb"
# 4. Core metabolome was calculated as in: "core_metabolome/core_metabolome_v3.pickle"

# %%
# All datasets on beta server
beta_raw = pd.read_csv('/Users/dis/PycharmProjects/neutal_loss_2/Metaspace_beta_2020_Feb.csv',
                       sep='\t')

# Good quality datasets
good_ds_list = list(pd.read_csv('good_ds_2020_Feb_25.txt').good_datasets)

# Filter for only good datasets
beta_raw = beta_raw[beta_raw['datasetId'].isin(good_ds_list)]

# Core metabolome
# core_metabolome = pd.read_pickle('core_metabolome_v1.pickle')

# %%
meta = beta_raw[['datasetId', 'group', 'analyzer', 'polarity', 'FDR@10%']].rename(columns=({'FDR@10%':'FDR10-v4'}))
meta.to_pickle('ds_id_meta.pickle')

# %%
beta_df = beta_raw.replace({',':''}, regex=True)
columns = ['datasetId', 'datasetName', 'polarity', 'organism', 'organismPart', 'analyzer', 
           'ionisationSource', 'maldiMatrix']
temp_df = beta_df[columns].copy(deep=True)
beta_df['query'] = temp_df.apply(lambda x: ','.join(x.dropna().values.tolist()), axis=1)
beta_df['result'] = ''

# %%
beta_df.shape
# Out:
# (433, 20)

# %%
#%%capture cap_out
i = 237 # 0
j = 432 # Max = 3248

while i <= j:
    x = "Current row is: " + str(i) + " of 432"
    print(x)
    i += 1
    row = beta_df.iloc[i,:]

    with open('/Users/dis/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_3.py', 'r') as file:
        filedata = file.read()

    filedata = filedata.replace('Literal_to_replace_ds_id', 
                                row.query)
    filedata = filedata.replace('Literal_to_replace_out', 
                                row.query.split(',')[0])

    with open('/Users/dis/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py', 'w') as file:
        file.write(filedata)
        
    # %run -i 'neutral_loss_report_beta_test_4.py'
# Out:
# Current row is: 237 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 741 annotations for 2018-08-01_14h19m50s @ 0.5
# Current row is: 238 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 741 annotations for 2018-08-01_14h20m09s @ 0.5
# Current row is: 239 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 741 annotations for 2018-08-01_14h23m16s @ 0.5
# Current row is: 240 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 741 annotations for 2018-08-01_14h23m33s @ 0.5
# Current row is: 241 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 741 annotations for 2018-08-01_14h23m58s @ 0.5
# Current row is: 242 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 910 annotations for 2018-08-01_14h27m24s @ 0.5
# Current row is: 243 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 910 annotations for 2018-08-01_14h27m50s @ 0.5
# Current row is: 244 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 910 annotations for 2018-08-01_14h28m11s @ 0.5
# Current row is: 245 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 894 annotations for 2018-08-03_15h42m22s @ 0.5
# Current row is: 246 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 989 annotations for 2018-09-12_09h16m30s @ 0.5
# Current row is: 247 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 399 annotations for 2018-09-13_00h55m36s @ 0.5
# Current row is: 248 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 376 annotations for 2018-09-13_00h55m56s @ 0.5
# Current row is: 249 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1002 annotations for 2018-09-14_22h42m37s @ 0.5
# Current row is: 250 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 760 annotations for 2018-06-13_21h09m17s @ 0.5
# Current row is: 251 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 887 annotations for 2018-06-14_00h45m31s @ 0.5
# Current row is: 252 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1069 annotations for 2018-06-16_05h29m11s @ 0.5
# Current row is: 253 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 339 annotations for 2018-09-01_00h55m05s @ 0.5
# Current row is: 254 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 369 annotations for 2018-09-04_00h48m58s @ 0.5
# Current row is: 255 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 378 annotations for 2018-09-07_00h49m45s @ 0.5
# Current row is: 256 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 353 annotations for 2018-09-07_00h52m21s @ 0.5
# Current row is: 257 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 305 annotations for 2018-09-07_01h02m31s @ 0.5
# Current row is: 258 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 303 annotations for 2018-09-23_07h53m38s @ 0.5
# Current row is: 259 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 579 annotations for 2018-10-06_02h51m57s @ 0.5
# Current row is: 260 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 773 annotations for 2018-10-07_12h42m25s @ 0.5
# Current row is: 261 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 737 annotations for 2018-10-07_14h40m17s @ 0.5
# Current row is: 262 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 799 annotations for 2018-10-08_01h26m58s @ 0.5
# Current row is: 263 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 747 annotations for 2018-10-15_11h30m30s @ 0.5
# Current row is: 264 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 807 annotations for 2018-10-16_01h42m26s @ 0.5
# Current row is: 265 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 443 annotations for 2018-10-17_22h16m34s @ 0.5
# Current row is: 266 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 236 annotations for 2018-10-17_22h21m06s @ 0.5
# Current row is: 267 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 809 annotations for 2018-10-19_01h06m20s @ 0.5
# Current row is: 268 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 276 annotations for 2018-10-20_22h35m05s @ 0.5
# Current row is: 269 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 435 annotations for 2018-10-29_11h02m58s @ 0.5
# Current row is: 270 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 19 annotations for 2018-11-05_21h41m29s @ 0.5
# Current row is: 271 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1184 annotations for 2018-11-21_21h31m33s @ 0.5
# Current row is: 272 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 912 annotations for 2018-11-21_21h36m35s @ 0.5
# Current row is: 273 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-01-14_16h38m58s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-01-14_16h38m58s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-01-14_16h38m58s not found
# Current row is: 274 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-01-15_10h41m44s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-01-15_10h41m44s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-01-15_10h41m44s not found
# Current row is: 275 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 468 annotations for 2019-01-24_23h23m35s @ 0.5
# Current row is: 276 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 286 annotations for 2019-01-25_05h18m40s @ 0.5
# Current row is: 277 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 753 annotations for 2019-01-28_00h48m00s @ 0.5
# Current row is: 278 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-02-08_11h28m33s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-02-08_11h28m33s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-02-08_11h28m33s not found
# Current row is: 279 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-02-13_10h27m43s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-02-13_10h27m43s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-02-13_10h27m43s not found
# Current row is: 280 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 295 annotations for 2018-10-30_11h52m30s @ 0.5
# Current row is: 281 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-02-26_15h42m13s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-02-26_15h42m13s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-02-26_15h42m13s not found
# Current row is: 282 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 199 annotations for 2019-03-06_23h29m19s @ 0.5
# Current row is: 283 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-12_13h11m58s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-12_13h11m58s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-03-12_13h11m58s not found
# Current row is: 284 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-20_14h40m00s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-20_14h40m00s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-03-20_14h40m00s not found
# Current row is: 285 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 628 annotations for 2019-03-22_10h16m54s @ 0.5
# Current row is: 286 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-25_10h46m44s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-25_10h46m44s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-03-25_10h46m44s not found
# Current row is: 287 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-26_13h12m52s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-26_13h12m52s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-03-26_13h12m52s not found
# Current row is: 288 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-26_13h16m45s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-26_13h16m45s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-03-26_13h16m45s not found
# Current row is: 289 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-26_13h17m28s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-26_13h17m28s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-03-26_13h17m28s not found
# Current row is: 290 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-29_15h44m43s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-03-29_15h44m43s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-03-29_15h44m43s not found
# Current row is: 291 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 552 annotations for 2019-04-05_10h09m00s @ 0.5
# Current row is: 292 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 552 annotations for 2019-04-05_13h17m06s @ 0.5
# Current row is: 293 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-08_15h57m21s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-08_15h57m21s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-08_15h57m21s not found
# Current row is: 294 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-08_15h59m06s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-08_15h59m06s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-08_15h59m06s not found
# Current row is: 295 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_16h54m58s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_16h54m58s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-09_16h54m58s not found
# Current row is: 296 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_16h55m16s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_16h55m16s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-09_16h55m16s not found
# Current row is: 297 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_16h55m38s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_16h55m38s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-09_16h55m38s not found
# Current row is: 298 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_16h55m53s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_16h55m53s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-09_16h55m53s not found
# Current row is: 299 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_17h09m22s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-09_17h09m22s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-09_17h09m22s not found
# Current row is: 300 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 603 annotations for 2019-04-12_03h52m15s @ 0.5
# Current row is: 301 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-15_16h44m01s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-15_16h44m01s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-15_16h44m01s not found
# Current row is: 302 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-17_15h35m38s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-17_15h35m38s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-17_15h35m38s not found
# Current row is: 303 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-17_15h59m34s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-17_15h59m34s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-17_15h59m34s not found
# Current row is: 304 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-17_16h30m02s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-17_16h30m02s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-04-17_16h30m02s not found
# Current row is: 305 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-17_18h32m13s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-04-17_18h32m13s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ...
# Current row is: 414 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-09-19_18h00m50s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-09-19_18h00m50s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-09-19_18h00m50s not found
# Current row is: 415 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-09-19_17h56m20s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-09-19_17h56m20s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-09-19_17h56m20s not found
# Current row is: 416 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 309 annotations for 2019-10-29_16h28m34s @ 0.5
# Current row is: 417 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 719 annotations for 2019-10-29_16h53m33s @ 0.5
# Current row is: 418 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 212 annotations for 2019-10-29_17h49m49s @ 0.5
# Current row is: 419 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 229 annotations for 2019-10-29_21h29m01s @ 0.5
# Current row is: 420 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 217 annotations for 2019-10-29_21h37m26s @ 0.5
# Current row is: 421 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-14_10h16m18s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-14_10h16m18s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-14_10h16m18s not found
# Current row is: 422 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 282 annotations for 2019-11-15_20h49m52s @ 0.5
# Current row is: 423 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 280 annotations for 2019-11-15_20h55m40s @ 0.5
# Current row is: 424 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-18_23h03m04s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-18_23h03m04s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-18_23h03m04s not found
# Current row is: 425 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-18_23h44m11s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-18_23h44m11s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-18_23h44m11s not found
# Current row is: 426 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-20_09h56m21s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-20_09h56m21s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-20_09h56m21s not found
# Current row is: 427 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 362 annotations for 2017-01-19_18h32m25s @ 0.5
# Current row is: 428 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 354 annotations for 2017-01-25_17h34m34s @ 0.5
# Current row is: 429 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 325 annotations for 2017-01-20_17h52m13s @ 0.5
# Current row is: 430 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-28_11h24m47s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-28_11h24m47s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-28_11h24m47s not found
# Current row is: 431 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 2087 annotations for 2019-12-04_00h41m47s @ 0.5
# Current row is: 432 of 432
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#       7     print(x)
#       8     i += 1
# ----> 9     row = beta_df.iloc[i,:]
#      10
#      11     with open('/Users/dis/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_3.py', 'r') as file:
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2090     def _getitem_tuple(self, tup):
#    2091
# -> 2092         self._has_valid_tuple(tup)
#    2093         try:
#    2094             return self._getitem_lowerdim(tup)
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     233                 raise IndexingError("Too many indexers")
#     234             try:
# --> 235                 self._validate_key(k, i)
#     236             except ValueError:
#     237                 raise ValueError(
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    2012             return
#    2013         elif is_integer(key):
# -> 2014             self._validate_integer(key, axis)
#    2015         elif isinstance(key, tuple):
#    2016             # a tuple should already have been caught by this point
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2086         len_axis = len(self.obj._get_axis(axis))
#    2087         if key >= len_axis or key < -len_axis:
# -> 2088             raise IndexError("single positional indexer is out-of-bounds")
#    2089
#    2090     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
i
cap_out.show()

# %%
# Counts reports
# path joining version for other paths
DIR = '/Users/dis/PycharmProjects/neutral_loss/good_nl_reports/reports'
print(len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))

# %%
original = sys.stdout
sys.stdout = open('cap_out_Feb__14_2020.txt', 'w')
cap_out.show()
sys.stdout = original

# %%
# Repeat download after all processing complete with reprocess turned off!
# Download to a fresh new folder

# %%
# Next script is: 
'http://localhost:8888/notebooks/PycharmProjects/neutral_loss/nl_0_3_clean_join_nb.ipynb'
