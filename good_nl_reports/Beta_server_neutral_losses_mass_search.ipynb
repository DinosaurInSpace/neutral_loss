# %%
import pandas as pd
import numpy as np
import sys
import os, os.path

# %% [markdown]
# The purpose of this experiment is to figure out how to best automate a larger number of searches on the beta server.  The goal, is to search all existing public datasets on the beta server with 'hdmb-v4' for the 'H2O' neutral loss, at FDR=0.5.  Data will later be filtered to FDR<=0.2 for parent, and FDR<=0.5 for neutral loss, since the current FDR calculations may unfairly penalize neutral losses.
#
# Here, we will use a subset of "high-quality" datasets from the top-4 labs submitting orbitrap/FTMS in the positive and negative ion modes.
#
# Data will be searched against a "core metabolome DB".

# %% [markdown]
# #Off-line steps:
# 1. Metadata as csv was downloaded from: https://beta.metaspace2020.eu/ on 2020 Feb 06.
# 2. Data were imported into Google Sheets, since formatting is comma seperated but then there are commas in text files:
# https://docs.google.com/spreadsheets/d/1DOLikG1euG-brCrMB5jrKwiu7bknPUVGVf8JsZXY3hM/edit?usp=sharing
# 3. Data were further filtered for quality as described above in: "neutral_loss/good_nl_reports/high_quality_data_investigations.ipynb"
# 4. Core metabolome was calculated as in: "core_metabolome/core_metabolome_v1.pickle"

# %%
# All datasets on beta server
beta_raw = pd.read_csv('/Users/dis/PycharmProjects/neutal_loss_2/Metaspace_beta_2020_Feb.csv',
                       sep='\t')

# Good quality datasets
good_ds_list = list(pd.read_csv('good_ds_2020_Feb_25.txt').good_datasets)

# Filter for only good datasets
beta_raw = beta_raw[beta_raw['datasetId'].isin(good_ds_list)]

# Core metabolome
# core_metabolome = pd.read_pickle('core_metabolome_v1.pickle')

# %%
meta = beta_raw[['datasetId', 'group', 'analyzer', 'polarity', 'FDR@10%']].rename(columns=({'FDR@10%':'FDR10-v4'}))
meta.to_pickle('ds_id_meta.pickle')

# %%
beta_df = beta_raw.replace({',':''}, regex=True)
columns = ['datasetId', 'datasetName', 'polarity', 'organism', 'organismPart', 'analyzer', 
           'ionisationSource', 'maldiMatrix']
temp_df = beta_df[columns].copy(deep=True)
beta_df['query'] = temp_df.apply(lambda x: ','.join(x.dropna().values.tolist()), axis=1)
beta_df['result'] = ''

# %%
beta_df.shape
# Out:
# (433, 20)

# %%
#%%capture cap_out
i = 0 # 0
j = 432 # Max = 3248

while i <= j:
    x = "Current row is: " + str(i) + " of 432"
    print(x)
    i += 1
    row = beta_df.iloc[i,:]

    with open('neutral_loss_report_beta_test_3.py', 'r') as file:
        filedata = file.read()

    filedata = filedata.replace('Literal_to_replace_ds_id', 
                                row.query)
    filedata = filedata.replace('Literal_to_replace_out', 
                                row.query.split(',')[0])

    with open('neutral_loss_report_beta_test_4.py', 'w') as file:
        file.write(filedata)
        
    # %run -i 'neutral_loss_report_beta_test_4.py'
# Out:
# Current row is: 0 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 659 annotations for 2018-10-12_09h25m16s @ 0.5
# Current row is: 1 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 709 annotations for 2018-10-16_09h53m21s @ 0.5
# Current row is: 2 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 806 annotations for 2018-10-31_10h26m49s @ 0.5
# Current row is: 3 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 928 annotations for 2018-11-08_15h29m23s @ 0.5
# Current row is: 4 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 736 annotations for 2019-01-17_19h54m30s @ 0.5
# Current row is: 5 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 2126 annotations for 2019-03-08_16h46m27s @ 0.5
# Current row is: 6 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 2945 annotations for 2019-03-12_08h57m03s @ 0.5
# Current row is: 7 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1879 annotations for 2019-06-21_08h59m52s @ 0.5
# Current row is: 8 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1269 annotations for 2019-06-21_13h02m14s @ 0.5
# Current row is: 9 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 2018 annotations for 2019-06-24_09h00m24s @ 0.5
# Current row is: 10 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1191 annotations for 2019-06-25_16h15m15s @ 0.5
# Current row is: 11 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1420 annotations for 2019-07-01_13h09m29s @ 0.5
# Current row is: 12 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1263 annotations for 2019-07-02_09h07m02s @ 0.5
# Current row is: 13 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 934 annotations for 2019-07-04_09h50m41s @ 0.5
# Current row is: 14 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 2412 annotations for 2019-07-09_11h25m35s @ 0.5
# Current row is: 15 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1417 annotations for 2019-07-09_11h26m26s @ 0.5
# Current row is: 16 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 520 annotations for 2019-08-05_13h09m17s @ 0.5
# Current row is: 17 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-19_09h49m15s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-19_09h49m15s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-19_09h49m15s not found
# Current row is: 18 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-19_17h59m17s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-19_17h59m17s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-19_17h59m17s not found
# Current row is: 19 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-27_11h08m37s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-27_11h08m37s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-27_11h08m37s not found
# Current row is: 20 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 685 annotations for 2017-08-04_12h38m01s @ 0.5
# Current row is: 21 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-18_10h46m15s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-18_10h46m15s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2018-06-18_10h46m15s not found
# Current row is: 22 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-09-14_18h15m42s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-09-14_18h15m42s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2018-09-14_18h15m42s not found
# Current row is: 23 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 2692 annotations for 2016-10-10_10h50m00s @ 0.5
# Current row is: 24 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 2652 annotations for 2016-11-15_12h00m00s @ 0.5
# Current row is: 25 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 270 annotations for 2018-03-26_22h32m23s @ 0.5
# Current row is: 26 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1241 annotations for 2018-02-22_10h25m27s @ 0.5
# Current row is: 27 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1040 annotations for 2016-10-14_17h51m23s @ 0.5
# Current row is: 28 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1690 annotations for 2018-01-10_12h49m21s @ 0.5
# Current row is: 29 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1059 annotations for 2018-01-04_15h10m02s @ 0.5
# Current row is: 30 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1330 annotations for 2018-01-04_14h36m35s @ 0.5
# Current row is: 31 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 445 annotations for 2017-12-21_07h22m01s @ 0.5
# Current row is: 32 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1153 annotations for 2017-12-20_16h49m07s @ 0.5
# Current row is: 33 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 455 annotations for 2017-12-20_16h32m25s @ 0.5
# Current row is: 34 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 987 annotations for 2017-12-20_16h31m52s @ 0.5
# Current row is: 35 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 844 annotations for 2017-12-20_16h30m17s @ 0.5
# Current row is: 36 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 319 annotations for 2017-12-20_16h29m39s @ 0.5
# Current row is: 37 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 586 annotations for 2017-12-20_16h28m12s @ 0.5
# Current row is: 38 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 412 annotations for 2017-12-20_16h27m04s @ 0.5
# Current row is: 39 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 673 annotations for 2017-12-20_16h24m55s @ 0.5
# Current row is: 40 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1158 annotations for 2017-08-07_14h26m32s @ 0.5
# Current row is: 41 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 909 annotations for 2017-12-11_15h07m56s @ 0.5
# Current row is: 42 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 912 annotations for 2017-12-11_15h07m13s @ 0.5
# Current row is: 43 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 948 annotations for 2017-12-11_15h06m45s @ 0.5
# Current row is: 44 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 805 annotations for 2017-12-07_17h00m26s @ 0.5
# Current row is: 45 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 901 annotations for 2017-11-27_16h07m06s @ 0.5
# Current row is: 46 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 917 annotations for 2017-11-27_16h06m20s @ 0.5
# Current row is: 47 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 937 annotations for 2017-11-27_16h05m41s @ 0.5
# Current row is: 48 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1284 annotations for 2016-12-01_18h42m02s @ 0.5
# Current row is: 49 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 283 annotations for 2017-10-10_15h38m32s @ 0.5
# Current row is: 50 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 507 annotations for 2016-12-16_22h08m42s @ 0.5
# Current row is: 51 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 776 annotations for 2017-02-09_16h35m32s @ 0.5
# Current row is: 52 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 569 annotations for 2016-12-16_22h08m23s @ 0.5
# Current row is: 53 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 611 annotations for 2016-12-16_22h08m07s @ 0.5
# Current row is: 54 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 490 annotations for 2016-12-16_22h07m51s @ 0.5
# Current row is: 55 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 608 annotations for 2016-12-16_22h10m58s @ 0.5
# Current row is: 56 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 650 annotations for 2016-12-16_22h10m19s @ 0.5
# Current row is: 57 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 898 annotations for 2016-12-16_22h12m34s @ 0.5
# Current row is: 58 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 908 annotations for 2016-12-19_19h31m16s @ 0.5
# Current row is: 59 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 776 annotations for 2017-02-09_19h49m02s @ 0.5
# Current row is: 60 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 413 annotations for 2017-09-14_13h43m01s @ 0.5
# Current row is: 61 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 373 annotations for 2017-09-08_17h00m55s @ 0.5
# Current row is: 62 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 418 annotations for 2017-09-08_10h22m41s @ 0.5
# Current row is: 63 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 274 annotations for 2017-09-07_14h11m40s @ 0.5
# Current row is: 64 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 312 annotations for 2016-09-22_11h16m16s @ 0.5
# Current row is: 65 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 909 annotations for 2017-08-30_14h30m02s @ 0.5
# Current row is: 66 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 481 annotations for 2017-08-25_07h57m51s @ 0.5
# Current row is: 67 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 468 annotations for 2017-08-18_16h00m58s @ 0.5
# Current row is: 68 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 434 annotations for 2017-08-16_11h15m04s @ 0.5
# Current row is: 69 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 512 annotations for 2017-08-16_08h30m18s @ 0.5
# Current row is: 70 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 179 annotations for 2017-08-16_07h50m21s @ 0.5
# Current row is: 71 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 341 annotations for 2017-08-15_19h58m16s @ 0.5
# Current row is: 72 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 497 annotations for 2017-08-15_19h13m44s @ 0.5
# Current row is: 73 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 342 annotations for 2017-08-15_18h01m27s @ 0.5
# Current row is: 74 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 465 annotations for 2017-08-15_15h02m08s @ 0.5
# Current row is: 75 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 617 annotations for 2017-08-15_13h02m38s @ 0.5
# Current row is: 76 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 746 annotations for 2017-08-15_02h18m25s @ 0.5
# Current row is: 77 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 771 annotations for 2017-08-15_02h17m49s @ 0.5
# Current row is: 78 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 760 annotations for 2017-08-10_06h56m06s @ 0.5
# Current row is: 79 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 689 annotations for 2017-08-09_10h07m28s @ 0.5
# Current row is: 80 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 665 annotations for 2017-08-09_10h07m05s @ 0.5
# Current row is: 81 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 674 annotations for 2017-08-09_10h06m42s @ 0.5
# Current row is: 82 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 688 annotations for 2017-08-09_10h06m25s @ 0.5
# Current row is: 83 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 654 annotations for 2017-08-09_03h02m01s @ 0.5
# Current row is: 84 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 734 annotations for 2017-08-09_01h24m04s @ 0.5
# Current row is: 85 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 644 annotations for 2017-08-08_14h30m45s @ 0.5
# Current row is: 86 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 650 annotations for 2017-08-08_14h30m25s @ 0.5
# Current row is: 87 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 680 annotations for 2017-08-08_14h30m09s @ 0.5
# Current row is: 88 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 782 annotations for 2017-08-08_14h29m48s @ 0.5
# Current row is: 89 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 781 annotations for 2017-08-08_14h29m07s @ 0.5
# Current row is: 90 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 771 annotations for 2017-08-08_14h28m01s @ 0.5
# Current row is: 91 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 775 annotations for 2017-08-08_14h27m05s @ 0.5
# Current row is: 92 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 807 annotations for 2017-08-08_14h18m50s @ 0.5
# Current row is: 93 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 776 annotations for 2017-08-08_14h05m38s @ 0.5
# Current row is: 94 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 742 annotations for 2017-08-08_09h06m39s @ 0.5
# Current row is: 95 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 732 annotations for 2017-08-08_09h05m39s @ 0.5
# Current row is: 96 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 738 annotations for 2017-08-08_09h04m59s @ 0.5
# Current row is: 97 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 761 annotations for 2017-08-08_09h04m28s @ 0.5
# Current row is: 98 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 726 annotations for 2017-08-08_09h04m00s @ 0.5
# Current row is: 99 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 375 annotations for 2017-08-08_08h49m46s @ 0.5
# Current row is: 100 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 700 annotations for 2017-08-04_12h39m49s @ 0.5
# Current row is: 101 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 707 annotations for 2017-08-04_12h38m34s @ 0.5
# Current row is: 102 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 720 annotations for 2017-08-04_12h36m19s @ 0.5
# Current row is: 103 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 778 annotations for 2017-08-04_12h35m23s @ 0.5
# Current row is: 104 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 731 annotations for 2017-08-04_12h34m49s @ 0.5
# Current row is: 105 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 775 annotations for 2017-08-04_12h34m05s @ 0.5
# Current row is: 106 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 792 annotations for 2017-08-04_12h33m17s @ 0.5
# Current row is: 107 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 848 annotations for 2017-08-04_12h32m36s @ 0.5
# Current row is: 108 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 544 annotations for 2017-08-03_12h25m10s @ 0.5
# Current row is: 109 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 372 annotations for 2017-08-02_00h09m50s @ 0.5
# Current row is: 110 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 430 annotations for 2017-08-02_00h07m28s @ 0.5
# Current row is: 111 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 690 annotations for 2017-08-01_07h52m24s @ 0.5
# Current row is: 112 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 706 annotations for 2017-08-01_07h51m51s @ 0.5
# Current row is: 113 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 727 annotations for 2017-08-01_07h51m06s @ 0.5
# Current row is: 114 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 690 annotations for 2017-08-01_07h50m35s @ 0.5
# Current row is: 115 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 701 annotations for 2017-08-01_07h50m05s @ 0.5
# Current row is: 116 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 729 annotations for 2017-08-01_07h49m27s @ 0.5
# Current row is: 117 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 722 annotations for 2017-08-01_07h48m41s @ 0.5
# Current row is: 118 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 751 annotations for 2017-08-01_07h47m38s @ 0.5
# Current row is: 119 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 715 annotations for 2017-08-01_07h46m52s @ 0.5
# Current row is: 120 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 732 annotations for 2017-08-01_07h45m52s @ 0.5
# Current row is: 121 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 718 annotations for 2017-08-01_07h45m10s @ 0.5
# Current row is: 122 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 732 annotations for 2017-08-01_07h44m05s @ 0.5
# Current row is: 123 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 704 annotations for 2017-08-01_07h43m16s @ 0.5
# Current row is: 124 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 748 annotations for 2017-08-01_07h42m41s @ 0.5
# Current row is: 125 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 726 annotations for 2017-08-01_07h41m55s @ 0.5
# Current row is: 126 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 756 annotations for 2017-08-01_07h41m18s @ 0.5
# Current row is: 127 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 810 annotations for 2017-08-01_07h40m37s @ 0.5
# Current row is: 128 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 801 annotations for 2017-08-01_07h39m54s @ 0.5
# Current row is: 129 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 448 annotations for 2017-07-31_12h54m18s @ 0.5
# Current row is: 130 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 705 annotations for 2017-07-21_14h46m39s @ 0.5
# Current row is: 131 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 720 annotations for 2017-07-21_14h46m19s @ 0.5
# Current row is: 132 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 709 annotations for 2017-07-21_09h23m33s @ 0.5
# Current row is: 133 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 730 annotations for 2017-07-21_09h23m08s @ 0.5
# Current row is: 134 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 709 annotations for 2017-07-21_09h20m28s @ 0.5
# Current row is: 135 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 701 annotations for 2017-07-21_09h19m20s @ 0.5
# Current row is: 136 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 692 annotations for 2017-07-21_09h19m02s @ 0.5
# Current row is: 137 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 693 annotations for 2017-07-21_09h18m43s @ 0.5
# Current row is: 138 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 664 annotations for 2017-07-21_09h18m17s @ 0.5
# Current row is: 139 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 709 annotations for 2017-07-20_14h23m17s @ 0.5
# Current row is: 140 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 703 annotations for 2017-07-20_14h22m38s @ 0.5
# Current row is: 141 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 731 annotations for 2017-07-18_10h12m54s @ 0.5
# Current row is: 142 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 755 annotations for 2017-07-18_10h12m23s @ 0.5
# Current row is: 143 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 760 annotations for 2017-07-18_10h11m46s @ 0.5
# Current row is: 144 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 724 annotations for 2017-07-18_10h11m20s @ 0.5
# Current row is: 145 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 780 annotations for 2017-07-18_10h04m10s @ 0.5
# Current row is: 146 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 292 annotations for 2016-09-22_11h16m11s @ 0.5
# Current row is: 147 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 365 annotations for 2016-09-22_11h16m40s @ 0.5
# Current row is: 148 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 179 annotations for 2017-07-07_07h37m30s @ 0.5
# Current row is: 149 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 301 annotations for 2017-06-22_08h41m52s @ 0.5
# Current row is: 150 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 595 annotations for 2017-06-02_07h44m31s @ 0.5
# Current row is: 151 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 198 annotations for 2017-03-14_05h52m34s @ 0.5
# Current row is: 152 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 216 annotations for 2017-03-14_05h52m52s @ 0.5
# Current row is: 153 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 193 annotations for 2017-03-14_05h54m15s @ 0.5
# Current row is: 154 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 219 annotations for 2017-03-14_05h55m54s @ 0.5
# Current row is: 155 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 234 annotations for 2017-03-14_06h02m26s @ 0.5
# Current row is: 156 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 232 annotations for 2017-03-14_06h00m37s @ 0.5
# Current row is: 157 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 192 annotations for 2017-03-14_06h00m36s @ 0.5
# Current row is: 158 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 194 annotations for 2017-03-14_05h57m36s @ 0.5
# Current row is: 159 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 161 annotations for 2017-03-14_05h58m20s @ 0.5
# Current row is: 160 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1156 annotations for 2017-02-23_08h53m07s @ 0.5
# Current row is: 161 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 353 annotations for 2016-09-22_11h16m38s @ 0.5
# Current row is: 162 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 736 annotations for 2017-02-17_20h48m57s @ 0.5
# Current row is: 163 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 688 annotations for 2017-02-17_14h56m37s @ 0.5
# Current row is: 164 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 708 annotations for 2017-02-17_14h41m43s @ 0.5
# Current row is: 165 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 152 annotations for 2017-03-16_11h11m12s @ 0.5
# Current row is: 166 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 766 annotations for 2017-03-16_09h28m17s @ 0.5
# Current row is: 167 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 207 annotations for 2017-03-15_11h40m11s @ 0.5
# Current row is: 168 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 451 annotations for 2017-03-14_14h35m55s @ 0.5
# Current row is: 169 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 451 annotations for 2017-03-14_14h32m59s @ 0.5
# Current row is: 170 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 923 annotations for 2017-01-19_15h48m03s @ 0.5
# Current row is: 171 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 995 annotations for 2017-02-24_03h51m09s @ 0.5
# Current row is: 172 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1089 annotations for 2017-03-05_11h21m26s @ 0.5
# Current row is: 173 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 133 annotations for 2017-03-11_19h47m36s @ 0.5
# Current row is: 174 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 277 annotations for 2017-03-11_19h45m05s @ 0.5
# Current row is: 175 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 133 annotations for 2017-03-11_19h45m33s @ 0.5
# Current row is: 176 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 277 annotations for 2017-03-11_19h48m10s @ 0.5
# Current row is: 177 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 893 annotations for 2016-12-21_14h25m44s @ 0.5
# Current row is: 178 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 312 annotations for 2016-12-21_14h07m58s @ 0.5
# Current row is: 179 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 924 annotations for 2016-12-21_09h49m12s @ 0.5
# Current row is: 180 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1308 annotations for 2016-10-21_07h18m06s @ 0.5
# Current row is: 181 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 503 annotations for 2016-09-22_11h16m15s @ 0.5
# Current row is: 182 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1131 annotations for 2016-12-01_18h38m52s @ 0.5
# Current row is: 183 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 941 annotations for 2017-03-06_14h15m50s @ 0.5
# Current row is: 184 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 850 annotations for 2017-03-06_14h15m09s @ 0.5
# Current row is: 185 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 503 annotations for 2017-04-05_10h31m07s @ 0.5
# Current row is: 186 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1020 annotations for 2017-03-06_09h55m19s @ 0.5
# Current row is: 187 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 927 annotations for 2017-03-06_09h42m26s @ 0.5
# Current row is: 188 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 994 annotations for 2017-03-06_09h05m45s @ 0.5
# Current row is: 189 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 587 annotations for 2016-11-18_06h01m50s @ 0.5
# Current row is: 190 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 784 annotations for 2017-01-22_12h01m38s @ 0.5
# Current row is: 191 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 333 annotations for 2016-09-22_11h16m23s @ 0.5
# Current row is: 192 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1464 annotations for 2016-12-01_18h11m49s @ 0.5
# Current row is: 193 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1032 annotations for 2016-12-20_17h39m05s @ 0.5
# Current row is: 194 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 362 annotations for 2016-09-22_11h16m27s @ 0.5
# Current row is: 195 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 669 annotations for 2017-02-24_13h22m14s @ 0.5
# Current row is: 196 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 64 annotations for 2018-05-19_20h09m18s @ 0.5
# Current row is: 197 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 65 annotations for 2018-05-19_20h09m31s @ 0.5
# Current row is: 198 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 93 annotations for 2018-05-19_20h09m46s @ 0.5
# Current row is: 199 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 990 annotations for 2018-05-20_22h16m33s @ 0.5
# Current row is: 200 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 880 annotations for 2018-05-20_22h29m50s @ 0.5
# Current row is: 201 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 726 annotations for 2018-05-20_22h50m27s @ 0.5
# Current row is: 202 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 380 annotations for 2018-05-21_18h57m46s @ 0.5
# Current row is: 203 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 338 annotations for 2018-05-24_11h23m11s @ 0.5
# Current row is: 204 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 255 annotations for 2018-05-29_11h23m11s @ 0.5
# Current row is: 205 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 205 annotations for 2018-05-29_11h27m19s @ 0.5
# Current row is: 206 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 220 annotations for 2018-05-29_11h27m32s @ 0.5
# Current row is: 207 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-01_01h08m12s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-01_01h08m12s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2018-06-01_01h08m12s not found
# Current row is: 208 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 291 annotations for 2018-06-08_08h57m39s @ 0.5
# Current row is: 209 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-15_11h08m52s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-15_11h08m52s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2018-06-15_11h08m52s not found
# Current row is: 210 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-25_15h25m53s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-25_15h25m53s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2018-06-25_15h25m53s not found
# Current row is: 211 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-26_15h33m47s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2018-06-26_15h33m47s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2018-06-26_15h33m47s not found
# Current row is: 212 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 832 annotations for 2018-07-05_10h44m16s @ 0.5
# Current row is: 213 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1018 annotations for 2018-07-05_13h22m46s @ 0.5
# Current row is: 214 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 654 annotations for 2018-07-05_15h25m32s @ 0.5
# Current row is: 215 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 314 annotations for 2018-07-12_05h35m16s @ 0.5
# Current row is: 216 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 432 annotations for 2018-07-12_05h46m53s @ 0.5
# Current row is: 217 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 442 annotations for 2018-07-14_04h47m52s @ 0.5
# Current row is: 218 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 371 annotations for 2018-07-14_04h49m34s @ 0.5
# Current row is: 219 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 470 annotations for 2018-07-14_04h53m26s @ 0.5
# Current row is: 220 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 954 annotations for 2018-07-23_12h10m59s @ 0.5
# Current row is: 221 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1220 annotations for 2018-07-31_16h20m14s @ 0.5
# Current row is: 222 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1489 annotations for 2018-07-31_16h20m56s @ 0.5
# Current row is: 223 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 801 annotations for 2018-08-01_10h39m53s @ 0.5
# Current row is: 224 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 801 annotations for 2018-08-01_11h02m19s @ 0.5
# Current row is: 225 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 801 annotations for 2018-08-01_11h05m36s @ 0.5
# Current row is: 226 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 801 annotations for 2018-08-01_11h08m28s @ 0.5
# ...
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-09-19_18h04m35s not found
# Current row is: 414 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-09-19_18h00m50s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-09-19_18h00m50s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-09-19_18h00m50s not found
# Current row is: 415 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-09-19_17h56m20s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-09-19_17h56m20s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-09-19_17h56m20s not found
# Current row is: 416 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 346 annotations for 2019-10-29_16h28m34s @ 0.5
# Current row is: 417 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 727 annotations for 2019-10-29_16h53m33s @ 0.5
# Current row is: 418 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 242 annotations for 2019-10-29_17h49m49s @ 0.5
# Current row is: 419 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 251 annotations for 2019-10-29_21h29m01s @ 0.5
# Current row is: 420 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 235 annotations for 2019-10-29_21h37m26s @ 0.5
# Current row is: 421 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-14_10h16m18s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-14_10h16m18s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-14_10h16m18s not found
# Current row is: 422 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 318 annotations for 2019-11-15_20h49m52s @ 0.5
# Current row is: 423 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 308 annotations for 2019-11-15_20h55m40s @ 0.5
# Current row is: 424 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-18_23h03m04s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-18_23h03m04s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-18_23h03m04s not found
# Current row is: 425 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-18_23h44m11s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-18_23h44m11s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-18_23h44m11s not found
# Current row is: 426 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-20_09h56m21s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-20_09h56m21s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-20_09h56m21s not found
# Current row is: 427 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 459 annotations for 2017-01-19_18h32m25s @ 0.5
# Current row is: 428 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 463 annotations for 2017-01-25_17h34m34s @ 0.5
# Current row is: 429 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 446 annotations for 2017-01-20_17h52m13s @ 0.5
# Current row is: 430 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-28_11h24m47s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2019-11-28_11h24m47s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2019-11-28_11h24m47s not found
# Current row is: 431 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 2305 annotations for 2019-12-04_00h41m47s @ 0.5
# Current row is: 432 of 432
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#       7     print(x)
#       8     i += 1
# ----> 9     row = beta_df.iloc[i,:]
#      10
#      11     with open('neutral_loss_report_beta_test_3.py', 'r') as file:
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2090     def _getitem_tuple(self, tup):
#    2091
# -> 2092         self._has_valid_tuple(tup)
#    2093         try:
#    2094             return self._getitem_lowerdim(tup)
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     233                 raise IndexingError("Too many indexers")
#     234             try:
# --> 235                 self._validate_key(k, i)
#     236             except ValueError:
#     237                 raise ValueError(
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    2012             return
#    2013         elif is_integer(key):
# -> 2014             self._validate_integer(key, axis)
#    2015         elif isinstance(key, tuple):
#    2016             # a tuple should already have been caught by this point
#
# ~/anaconda3/envs/lcenv/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2086         len_axis = len(self.obj._get_axis(axis))
#    2087         if key >= len_axis or key < -len_axis:
# -> 2088             raise IndexError("single positional indexer is out-of-bounds")
#    2089
#    2090     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
i
cap_out.show()

# %%
# Counts reports
# path joining version for other paths
DIR = '/Users/dis/PycharmProjects/neutral_loss/good_nl_reports/reports'
print(len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))
# Out:
# 318

# %%
original = sys.stdout
sys.stdout = open('cap_out_Feb__14_2020.txt', 'w')
cap_out.show()
sys.stdout = original

# %%
# Repeat download after all processing complete with reprocess turned off!
# Download to a fresh new folder

# %%
# Next script is: 
'http://localhost:8888/notebooks/PycharmProjects/neutral_loss/nl_0_3_clean_join_nb.ipynb'
