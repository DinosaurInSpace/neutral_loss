# %%
import pandas as pd
import numpy as np
import sys
import os, os.path

# %% [markdown]
# The purpose of this experiment is to figure out how to best automate a larger number of searches on the beta server.  The goal, is to search all existing public datasets on the beta server with 'core_metabolome_v3' for the 'H2O' neutral loss, at FDR=0.5.  Data will later be filtered to FDR<=0.2 for parent, and FDR<=0.5 for neutral loss, since the current FDR calculations may unfairly penalize neutral losses.
#
# Here, we will use a subset of "high-quality" datasets from the top-4 labs submitting orbitrap/FTMS in the positive and negative ion modes.
#
# Data will be searched against a "core metabolome DB".

# %% [markdown]
# #Off-line steps:
# 1. Metadata as csv was downloaded from: https://beta.metaspace2020.eu/ on 2020 Feb 06.
# 2. Data were imported into Google Sheets, since formatting is comma seperated but then there are commas in text files:
# https://docs.google.com/spreadsheets/d/1DOLikG1euG-brCrMB5jrKwiu7bknPUVGVf8JsZXY3hM/edit?usp=sharing
# 3. Data were further filtered for quality as described above in: "neutral_loss/good_nl_reports/high_quality_data_investigations.ipynb"
# 4. Core metabolome was calculated as in: "core_metabolome/core_metabolome_v3.pickle"

# %%
# All datasets on beta server
beta_raw = pd.read_csv('/Users/dis/PycharmProjects/neutal_loss_2/Metaspace_beta_2020_Feb.csv',
                       sep='\t')

# Good quality datasets
good_ds_list = list(pd.read_csv('good_ds_2020_Feb_25.txt').good_datasets)

# Filter for only good datasets
beta_raw = beta_raw[beta_raw['datasetId'].isin(good_ds_list)]

# Core metabolome
# core_metabolome = pd.read_pickle('core_metabolome_v1.pickle')

# %%
meta = beta_raw[['datasetId', 'group', 'analyzer', 'polarity', 'FDR@10%']].rename(columns=({'FDR@10%':'FDR10-v4'}))
meta.to_pickle('ds_id_meta.pickle')

# %%
beta_df = beta_raw.replace({',':''}, regex=True)
columns = ['datasetId', 'datasetName', 'polarity', 'organism', 'organismPart', 'analyzer', 
           'ionisationSource', 'maldiMatrix']
temp_df = beta_df[columns].copy(deep=True)
beta_df['query'] = temp_df.apply(lambda x: ','.join(x.dropna().values.tolist()), axis=1)
beta_df['result'] = ''

# %%
beta_df.shape
# Out:
# (433, 20)

# %%
#%%capture cap_out
i = 0 # 0
j = 432 # Max = 3248

while i <= j:
    x = "Current row is: " + str(i) + " of 432"
    print(x)
    i += 1
    row = beta_df.iloc[i,:]

    with open('/Users/dis/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_3.py', 'r') as file:
        filedata = file.read()

    filedata = filedata.replace('Literal_to_replace_ds_id', 
                                row.query)
    filedata = filedata.replace('Literal_to_replace_out', 
                                row.query.split(',')[0])

    with open('/Users/dis/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py', 'w') as file:
        file.write(filedata)
        
    # %run -i 'neutral_loss_report_beta_test_4.py'
# Out:
# Current row is: 0 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 637 annotations for 2018-10-12_09h25m16s @ 0.5
# Current row is: 1 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 626 annotations for 2018-10-16_09h53m21s @ 0.5
# Current row is: 2 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 680 annotations for 2018-10-31_10h26m49s @ 0.5
# Current row is: 3 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 739 annotations for 2018-11-08_15h29m23s @ 0.5
# Current row is: 4 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 678 annotations for 2019-01-17_19h54m30s @ 0.5
# Current row is: 5 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1533 annotations for 2019-03-08_16h46m27s @ 0.5
# Current row is: 6 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 2406 annotations for 2019-03-12_08h57m03s @ 0.5
# Current row is: 7 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1002 annotations for 2019-06-21_08h59m52s @ 0.5
# Current row is: 8 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got
of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 126 annotations for 2016-12-16_22h08m42s @ 0.5
# Current row is: 51 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 363 annotations for 2017-02-09_16h35m32s @ 0.5
# Current row is: 52 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 124 annotations for 2016-12-16_22h08m23s @ 0.5
# Current row is: 53 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 138 annotations for 2016-12-16_22h08m07s @ 0.5
# Current row is: 54 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 117 annotations for 2016-12-16_22h07m51s @ 0.5
# Current row is: 55 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 229 annotations for 2016-12-16_22h10m58s @ 0.5
# Current row is: 56 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 273 annotations for 2016-12-16_22h10m19s @ 0.5
# Current row is: 57 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 360 annotations for 2016-12-16_22h12m34s @ 0.5
# Current row is: 58 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 475 annotations for 2016-12-19_19h31m16s @ 0.5
# Current row is: 59 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 363 annotations for 2017-02-09_19h49m02s @ 0.5
# Current row is: 60 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 293 annotations for 2017-09-14_13h43m01s @ 0.5
# Current row is: 61 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 194 annotations for 2017-09-08_17h00m55s @ 0.5
# Current row is: 62 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 409 annotations for 2017-09-08_10h22m41s @ 0.5
# Current row is: 63 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 192 annotations for 2017-09-07_14h11m40s @ 0.5
# Current row is: 64 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <module>
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2016-09-22_11h16m16s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in <listcomp>(.0)
#     259
#     260 if reprocess_not_downloading != True:
# --> 261     nl_stats = pd.concat([get_ds_neutral_loss_stats(ds_id, MAX_FDR) for ds_id in DATASETS_WITH_NL.ds_id])
#     262     nl_stats.to_pickle(f'{BASE_PATH}/2016-09-22_11h16m16s.pickle')
#     263
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_ds_neutral_loss_stats(ds_id, fdr)
#     205
#     206 def get_ds_neutral_loss_stats(ds_id, fdr):
# --> 207     anns_df, images, mask, h, w = get_single_dataset_images(ds_id, fdr)
#     208     suffixes = [nl.replace('-','_') for nl in NEUTRAL_LOSSES]
#     209     print(f'Got {len(anns_df)} annotations for {ds_id} @ {fdr}')
#
# ~/PycharmProjects/neutral_loss/good_nl_reports/neutral_loss_report_beta_test_4.py in get_single_dataset_images(ds_id, fdr)
#     170                                                            hotspot_percentile=99)
#     171     else:
# --> 172         raise Exception(f'{ds_id} not found')
#     173
#     174     anns_df = pd.DataFrame([
#
# Exception: 2016-09-22_11h16m16s not found
# Current row is: 65 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 596 annotations for 2017-08-30_14h30m02s @ 0.5
# Current row is: 66 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 385 annotations for 2017-08-25_07h57m51s @ 0.5
# Current row is: 67 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 302 annotations for 2017-08-18_16h00m58s @ 0.5
# Current row is: 68 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 319 annotations for 2017-08-16_11h15m04s @ 0.5
# Current row is: 69 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 364 annotations for 2017-08-16_08h30m18s @ 0.5
# Current row is: 70 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 129 annotations for 2017-08-16_07h50m21s @ 0.5
# Current row is: 71 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 252 annotations for 2017-08-15_19h58m16s @ 0.5
# Current row is: 72 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 388 annotations for 2017-08-15_19h13m44s @ 0.5
# Current row is: 73 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 267 annotations for 2017-08-15_18h01m27s @ 0.5
# Current row is: 74 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 313 annotations for 2017-08-15_15h02m08s @ 0.5
# Current row is: 75 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 515 annotations for 2017-08-15_13h02m38s @ 0.5
# Current row is: 76 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 662 annotations for 2017-08-15_02h18m25s @ 0.5
# Current row is: 77 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 682 annotations for 2017-08-15_02h17m49s @ 0.5
# Current row is: 78 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 693 annotations for 2017-08-10_06h56m06s @ 0.5
# Current row is: 79 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 707 annotations for 2017-08-09_10h07m28s @ 0.5
# Current row is: 80 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got
of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 131 annotations for 2017-03-16_11h11m12s @ 0.5
# Current row is: 166 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 549 annotations for 2017-03-16_09h28m17s @ 0.5
# Current row is: 167 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 133 annotations for 2017-03-15_11h40m11s @ 0.5
# Current row is: 168 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 327 annotations for 2017-03-14_14h35m55s @ 0.5
# Current row is: 169 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 327 annotations for 2017-03-14_14h32m59s @ 0.5
# Current row is: 170 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 813 annotations for 2017-01-19_15h48m03s @ 0.5
# Current row is: 171 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 778 annotations for 2017-02-24_03h51m09s @ 0.5
# Current row is: 172 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 780 annotations for 2017-03-05_11h21m26s @ 0.5
# Current row is: 173 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 98 annotations for 2017-03-11_19h47m36s @ 0.5
# Current row is: 174 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 198 annotations for 2017-03-11_19h45m05s @ 0.5
# Current row is: 175 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 98 annotations for 2017-03-11_19h45m33s @ 0.5
# Current row is: 176 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 198 annotations for 2017-03-11_19h48m10s @ 0.5
# Current row is: 177 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 835 annotations for 2016-12-21_14h25m44s @ 0.5
# Current row is: 178 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 156 annotations for 2016-12-21_14h07m58s @ 0.5
# Current row is: 179 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 866 annotations for 2016-12-21_09h49m12s @ 0.5
# Current row is: 180 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 234 annotations for 2016-10-21_07h18m06s @ 0.5
# Current row is: 181 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 494 annotations for 2016-09-22_11h16m15s @ 0.5
# Current row is: 182 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1232 annotations for 2016-12-01_18h38m52s @ 0.5
# Current row is: 183 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 964 annotations for 2017-03-06_14h15m50s @ 0.5
# Current row is: 184 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 807 annotations for 2017-03-06_14h15m09s @ 0.5
# Current row is: 185 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 288 annotations for 2017-04-05_10h31m07s @ 0.5
# Current row is: 186 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1008 annotations for 2017-03-06_09h55m19s @ 0.5
# Current row is: 187 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 901 annotations for 2017-03-06_09h42m26s @ 0.5
# Current row is: 188 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 944 annotations for 2017-03-06_09h05m45s @ 0.5
# Current row is: 189 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 551 annotations for 2016-11-18_06h01m50s @ 0.5
# Current row is: 190 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 591 annotations for 2017-01-22_12h01m38s @ 0.5
# Current row is: 191 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 334 annotations for 2016-09-22_11h16m23s @ 0.5
# Current row is: 192 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 1383 annotations for 2016-12-01_18h11m49s @ 0.5
# Current row is: 193 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 947 annotations for 2016-12-20_17h39m05s @ 0.5
# Current row is: 194 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 361 annotations for 2016-09-22_11h16m27s @ 0.5
# Current row is: 195 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 647 annotations for 2017-02-24_13h22m14s @ 0.5
# Current row is: 196 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 7 annotations for 2018-05-19_20h09m18s @ 0.5
# Current row is: 197 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 7 annotations for 2018-05-19_20h09m31s @ 0.5
# Current row is: 198 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 11 annotations for 2018-05-19_20h09m46s @ 0.5
# Current row is: 199 of 432
# Unauthorized. Only public but not private datasets will be accessible.
# Got 924 annotations for 2018-05-20_22h16m33s @ 0.5
# Current row is: 200 of 432
# Unauthorized. Only public but not private datasets will be accessible.

# %%
i
cap_out.show()

# %%
# Counts reports
# path joining version for other paths
DIR = '/Users/dis/PycharmProjects/neutral_loss/good_nl_reports/reports'
print(len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))
# Out:
# 318

# %%
original = sys.stdout
sys.stdout = open('cap_out_Feb__14_2020.txt', 'w')
cap_out.show()
sys.stdout = original

# %%
# Repeat download after all processing complete with reprocess turned off!
# Download to a fresh new folder

# %%
# Next script is: 
'http://localhost:8888/notebooks/PycharmProjects/neutral_loss/nl_0_3_clean_join_nb.ipynb'
